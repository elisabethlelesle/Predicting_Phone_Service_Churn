# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set()

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Drop missing value

# %%
#When I try to cek every feature that has missing value, all off the have same missing value possition
#the missing value data start from index 0-1008 (1009), so I drop the row
# df_cekNaN=df[df['gender'].isnull()]
# df_cekNaN

# %%
#drop missing value row
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# ### Mapping categorical Data

# %%
#gender
ax = df.gender.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['gender'] =df['gender'].map({'Male':0,'Female':1})

# %%
#SeniorCitizen
ax = df.SeniorCitizen.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
#Partner
ax = df.Partner.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Partner']=df['Partner'].map({'No':0,'Yes':1})

# %%
#Dependents
ax = df.Dependents.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Dependents']=df['Dependents'].map({'No':0, 'Yes':1})

# %%
#tenure
df['tenure'] = df['tenure'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['tenure'])
plt.show()
# Out:
# /Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#PhoneService
ax = df.PhoneService.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PhoneService']=df['PhoneService'].map({'No':0, 'Yes':1})

# %%
#MultipleLines
ax = df.MultipleLines.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['MultipleLines']=df['MultipleLines'].map({'No phone service':0, 'No':1, 'Yes':2})

# %%
#InternetService
ax = df.InternetService.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['InternetService']=df['InternetService'].map({'No':0, 'DSL':1, 'Fiber optic':2})

# %%
#OnlineSecurity
ax = df.OnlineSecurity.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['OnlineSecurity']=df['OnlineSecurity'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#OnlineBackup
ax = df.OnlineBackup.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['OnlineBackup']=df['OnlineBackup'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#DeviceProtection
ax = df.DeviceProtection.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['DeviceProtection']=df['DeviceProtection'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#TechSupport
ax = df.TechSupport.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['TechSupport']=df['TechSupport'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#StreamingTV
ax = df.StreamingTV.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['StreamingTV']=df['StreamingTV'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#StreamingMovies
ax = df.StreamingMovies.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['StreamingMovies']=df['StreamingMovies'].map({'No internet service':0, 'No':1, 'Yes':2})

# %%
#Contract
ax = df.Contract.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Contract']=df['Contract'].map({'Month-to-month':0, 'One year':1, 'Two year':2})

# %%
#PaperlessBilling
ax = df.PaperlessBilling.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PaperlessBilling']=df['PaperlessBilling'].map({'No':0, 'Yes':1})

# %%
#PaymentMethod
ax = df.PaymentMethod.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['PaymentMethod']=df['PaymentMethod'].map({'Electronic check':0, 'Mailed check':1, 'Bank transfer (automatic)':2, 'Credit card (automatic)':3})

# %%
#MonthlyCharges
df['MonthlyCharges'] = df['MonthlyCharges'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['MonthlyCharges'])
plt.show()
# Out:
# /Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#TotalCharges
#I got an error in this feature when I check, some features have null value like " ", 
#so I changed it first
df["TotalCharges"] = df["TotalCharges"].replace(" ", 0)

df['TotalCharges'] = df['TotalCharges'].astype(float)
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df['TotalCharges'])
plt.show()
# Out:
# /Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Churn
ax = df.Churn.value_counts().plot(kind='bar')

for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))

# %%
df['Churn']=df['Churn'].map({'No':0, 'Yes':1})

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       1              0        1           0     1.0
# 1  5575-GNVDE       0              0        0           0    34.0
# 2  3668-QPYBK       0              0        0           0     2.0
# 3  7795-CFOCW       0              0        0           0    45.0
# 4  9237-HQITU       1              0        0           0     2.0
#
#    PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# 0             0              0                1               1  ...
# 1             1              1                1               2  ...
# 2             1              1                1               2  ...
# 3             0              0                1               2  ...
# 4             1              1                2               1  ...
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 1            1            1                1         0
# ...

# %% [markdown]
# ### Check Feature Correlation

# %%
plt.figure(figsize=(20,8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
df.corr()['Churn'].sort_values(ascending=False)
# Out:
# Churn               1.000000
# InternetService     0.316846
# MonthlyCharges      0.193356
# PaperlessBilling    0.191825
# StreamingTV         0.164673
# StreamingMovies     0.163220
# SeniorCitizen       0.150889
# DeviceProtection    0.084654
# OnlineBackup        0.074205
# MultipleLines       0.036310
# TechSupport         0.027037
# OnlineSecurity      0.023309
# PhoneService        0.011942
# gender              0.008612
# Partner            -0.150448
# Dependents         -0.164221
# TotalCharges       -0.198324
# PaymentMethod      -0.262818
# tenure             -0.352229
# Contract           -0.396713
# Name: Churn, dtype: float64

# %% [markdown]
# ### Balancing the data

# %%
df['Churn'].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %%
from sklearn.utils import resample

fraud = df[df['Churn'] ==0]
not_fraud = df[df['Churn'] == 1]

balance_data = resample(fraud,
                        replace=True,
                        n_samples = len(not_fraud),
                        random_state=50)
df_balance = pd.concat([not_fraud, balance_data])
df_balance.Churn.value_counts()
# Out:
# 1    1869
# 0    1869
# Name: Churn, dtype: int64

# %% [markdown]
# ### Shuffle the Data

# %%
df_balance = df_balance.sample(frac=1)

# %% [markdown]
# ### Normalization

# %%
df_feature = df_balance.drop(['Churn','customerID'], axis=1)
df_label = df_balance['Churn']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(df_feature)
df_feature_scaler = scaler.transform(df_feature) #return in ndarray

#convert to dataframe
df_feature_scaler = pd.DataFrame(data=df_feature_scaler,columns=df_feature.columns)
df_feature_scaler.head()
# Out:
#      gender  SeniorCitizen   Partner  Dependents    tenure  PhoneService  \
# 0 -0.989885       -0.49347 -0.897176   -0.587442 -1.112553      0.323939
# 1 -0.989885       -0.49347 -0.897176   -0.587442 -1.070868      0.323939
# 2  1.010218       -0.49347  1.114608    1.702296  1.597012      0.323939
# 3  1.010218       -0.49347  1.114608   -0.587442 -0.612326      0.323939
# 4  1.010218       -0.49347 -0.897176   -0.587442 -0.904125      0.323939
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0      -0.520653        -1.820709       -1.708901     -1.709759
# 1      -0.520653        -0.477810       -0.134370     -0.228628
# 2       1.036309         0.865088       -0.134370      1.252502
# 3       1.036309        -0.477810        1.440161      1.252502
# 4      -0.520653        -1.820709       -1.708901     -1.709759
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# ...

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df_feature_scaler, df_label, test_size=0.2, random_state=27)

# %% [markdown]
# ## Classification Using Sklearn

# %% [markdown]
# ### Grid Search CV Ensemble Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
params = {'min_samples_leaf':[1,2,3],
          'min_samples_split':[2,3,4,5],
          'min_weight_fraction_leaf':[0.0,0.04,0.07],
          'n_estimators':[115,125,135],
          'criterion':['gini','entropy'],
          'class_weight':['None','balanced'],
          'max_features':['auto', 'sqrt', 'log2']}
model = RandomForestClassifier()
gsc = GridSearchCV(model, params, scoring='roc_auc', cv=5, return_train_score=True, n_jobs = 10)

# %% [markdown]
# ### Grid Search CV Learning and get best parameter

# %%
gsc.fit(X_train,y_train)
# Out:
# /Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 3240 fits failed out of a total of 6480.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 3240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/ensemble/_forest.py", line 367, in fit
#     y, expanded_class_weight = self._validate_y_class_weight(y)
# ...

# %%
print(gsc.best_params_)
print(gsc.best_score_)
# Out:
# {'class_weight': 'balanced', 'criterion': 'gini', 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'min_weight_fraction_leaf': 0.0, 'n_estimators': 125}
# 0.8551649310410399

# %% [markdown]
# ### Learning Model "RandomForest"

# %%
model = RandomForestClassifier(class_weight = 'balanced',
                               criterion = 'gini', 
                               max_features = 'auto',
                               min_samples_leaf = 3, 
                               min_samples_split = 4, 
                               min_weight_fraction_leaf = 0.0, 
                               n_estimators = 125)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', min_samples_leaf=3,
#                        min_samples_split=4, n_estimators=125)

# %%
model.score(X_train, y_train)
# Out:
# 0.903010033444816

# %%
from sklearn.metrics import accuracy_score
test_pred = model.predict(X_test)
accuracy_score(test_pred, y_test)
# Out:
# 0.766042780748663

# %% [markdown]
# ### Grid Search CV SVM

# %%
from sklearn import svm
from sklearn.model_selection import GridSearchCV
params = {'C': [1,2,3],
          'kernel': ['linear', 'poly', 'rbf'],
          'gamma':['scale','auto'],
          'class_weight':['None', 'dict', 'balanced']}
model = svm.SVC()
gsc_svm = GridSearchCV(model, params, scoring='roc_auc', cv=5, return_train_score=True, n_jobs = 5)

# %% [markdown]
# ### Grid Search CV Learning and get best parameter

# %%
gsc_svm.fit(X_train,y_train)
# Out:
# /Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:372: FitFailedWarning:
# 180 fits failed out of a total of 270.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 90 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/elisabethlelesle/opt/anaconda3/lib/python3.9/site-packages/sklearn/svm/_base.py", line 199, in fit
#     y = self._validate_targets(y)
# ...

# %%
print(gsc_svm.best_params_)
print(gsc_svm.best_score_)
# Out:
# {'C': 2, 'class_weight': 'balanced', 'gamma': 'scale', 'kernel': 'linear'}
# 0.8414559121262626

# %% [markdown]
# ### Learning Model "SVM"

# %%
model = svm.SVC(C = 1,
                class_weight = 'balanced', 
                gamma = 'scale', 
                kernel = 'linear')

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=1, class_weight='balanced', kernel='linear')

# %%
model.score(X_train, y_train)
# Out:
# 0.7618729096989967

# %%
from sklearn.metrics import accuracy_score
test_pred = model.predict(X_test)
accuracy_score(test_pred, y_test)
# Out:
# 0.7419786096256684

# %%
x = pd.DataFrame()
x['feature'] = df_feature.columns 
x['corelation'] = np.array(model.coef_)[0]
x.sort_values(by=['corelation'], ascending=False)
# Out:
#              feature  corelation
# 18      TotalCharges    1.011682
# 7    InternetService    0.755735
# 12       StreamingTV    0.260794
# 13   StreamingMovies    0.185896
# 6      MultipleLines    0.097680
# 15  PaperlessBilling    0.080721
# 5       PhoneService    0.050472
# 9       OnlineBackup    0.031745
# 10  DeviceProtection    0.030440
# 0             gender    0.022213
# 1      SeniorCitizen    0.019675
# 3         Dependents    0.011100
# 11       TechSupport    0.005145
# 2            Partner   -0.004942
# 16     PaymentMethod   -0.063882
# 8     OnlineSecurity   -0.072305
# 14          Contract   -0.715842
# 17    MonthlyCharges   -0.840577
# 4             tenure   -1.263860

# %% [markdown]
# ## Deep Learning Classification Using CNN

# %% [markdown]
# ### Split data into train(train, validation) and test

# %%
from sklearn.model_selection import train_test_split

X_big, X_test, y_big, y_test = train_test_split(df_feature_scaler, df_label, test_size=0.2, random_state=27)
#becase the data isn't too much, so I take the validation data from train data
X_train, X_val, y_train, y_val = train_test_split(X_big, y_big, test_size=0.2, random_state=27)

# %%
print(X_big.shape, X_val.shape, X_test.shape)
# Out:
# (2990, 19) (598, 19) (748, 19)

# %% [markdown]
# ### Save data to NPZ format

# %%
np.savez('telco_train', inputs=X_train, targets=y_train)
np.savez('telco_val', inputs=X_val, targets=y_val)
np.savez('telco_test', inputs=X_test, targets=y_test)

# %% [markdown]
# ### Load NPZ data

# %%
npz_train = np.load('telco_train.npz')
train_inputs, train_targets = npz_train['inputs'].astype(np.float), npz_train['targets'].astype(int)

npz_val = np.load('telco_val.npz')
val_inputs, val_targets = npz_val['inputs'].astype(np.float), npz_val['targets'].astype(int)

npz_test = np.load('telco_test.npz')
test_inputs, test_targets = npz_test['inputs'].astype(np.float), npz_test['targets'].astype(int)
# Out:
# /var/folders/cs/ltjwpn4s2cv_j8fzst8yww5m0000gn/T/ipykernel_9822/2458054398.py:2: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   train_inputs, train_targets = npz_train['inputs'].astype(np.float), npz_train['targets'].astype(int)
# /var/folders/cs/ltjwpn4s2cv_j8fzst8yww5m0000gn/T/ipykernel_9822/2458054398.py:5: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %% [markdown]
# ### Model

# %%
import tensorflow as tf
hidden_layer_size = 150
output_size = 2 #0 and 1

#3 hidden layer, depth 100
model = tf.keras.Sequential([
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(hidden_layer_size, activation='relu'),
    tf.keras.layers.Dense(output_size, activation='softmax')
])

#optimizer
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

early_stopping = tf.keras.callbacks.EarlyStopping(patience=2)
history = model.fit(train_inputs,
          train_targets,
          batch_size = 200,
          epochs = 20,
          callbacks = [early_stopping],
          validation_data = (val_inputs, val_targets),
          verbose = 2)

# %%
def plot_learningCurve(history, epochs):
  epoch_range = range(1, epochs+1)
  plt.plot(epoch_range, history.history['accuracy'])
  plt.plot(epoch_range, history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.xlabel('Epoch')
  plt.ylabel('Accuracy')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

  plt.plot(epoch_range, history.history['loss'])
  plt.plot(epoch_range, history.history['val_loss'])
  plt.title('Model Loss')
  plt.xlabel('Epoch')
  plt.ylabel('Loss')
  plt.legend(['Train', 'Val'], loc='upper right')
  plt.show()

# %%
plot_learningCurve(history, 5)

# %%
test_loss, test_accuracy = model.evaluate(test_inputs, test_targets)
print("Test loss: {0:.2f} and Test accuracy: {1:.2f}% ".format(test_loss,test_accuracy*100))
